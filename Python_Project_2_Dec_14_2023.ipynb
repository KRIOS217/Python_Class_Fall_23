# %% [markdown]
# <a href="https://colab.research.google.com/github/KRIOS217/Python_Class_Fall_23/blob/main/Python_Project_2_Dec_14_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **The goal of this project is to analyze diabetes data**
# -pick any group in this dataset as an initial comparison point
# -pick a feature/measure/indicator
# -compare above group to any other (different) group - you only need to do one additional group comparison (but you’re welcome to do more comparisons if you feel compelled to do so)
# -the analysis should include some descriptive statistics
# -the analysis should include one cleaning task (or more)
# -the analysis should include one visualization (or more)
# -the analysis should include a brief conclusion statement

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
import pandas as pd
from numpy.random import randn
np.random.seed(123)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# %%
df.shape
# Out:
# (101766, 50)

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.tail()
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# encounter_id                0
# patient_nbr                 0
# race                        0
# gender                      0
# age                         0
# weight                      0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# payer_code                  0
# medical_specialty           0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# diag_1                      0
# diag_2                      0
# diag_3                      0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# ...

# %%
# Drop column 'weight'
df2= df.drop(['weight'] , axis=1)
df2
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 0            2278392      8222157        Caucasian  Female   [0-10)
# 1             149190     55629189        Caucasian  Female  [10-20)
# 2              64410     86047875  AfricanAmerican  Female  [20-30)
# 3             500364     82442376        Caucasian    Male  [30-40)
# 4              16680     42519267        Caucasian    Male  [40-50)
# ...              ...          ...              ...     ...      ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)
# 101763     443854148     41088789        Caucasian    Male  [70-80)
# 101764     443857166     31693671        Caucasian  Female  [80-90)
# 101765     443867222    175429310        Caucasian    Male  [70-80)
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                       6                        25                    1
# ...

# %%
# Total count of gender in the dataset
df2.groupby(['gender'])['gender'].count().sort_index(ascending=True)
# Out:
# gender
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: gender, dtype: int64

# %%
# Total count by race & gender in the dataset
df2.groupby(['race','gender'])['race'].count().sort_index(ascending=True)
# Out:
# race             gender
# ?                Female              1133
#                  Male                1138
#                  Unknown/Invalid        2
# AfricanAmerican  Female             11728
#                  Male                7482
# Asian            Female               318
#                  Male                 323
# Caucasian        Female             39689
#                  Male               36410
# Hispanic         Female              1092
#                  Male                 945
# Other            Female               748
#                  Male                 757
#                  Unknown/Invalid        1
# Name: race, dtype: int64

# %% [markdown]
# 'diabetesMed' column use to find how many people take diabetes medication 'YES' and were readmitted to hospital. Conclusion would be that those who take the meds have a lower readmittance rate. Can also compare with 'insulin;

# %%
# Filter by specific value(s)
filter1 = df2[(df['diabetesMed'] == 'Yes')]
filter1.head(5)
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 1        149190     55629189        Caucasian  Female  [10-20)
# 2         64410     86047875  AfricanAmerican  Female  [20-30)
# 3        500364     82442376        Caucasian    Male  [30-40)
# 4         16680     42519267        Caucasian    Male  [40-50)
# 5         35754     82637451        Caucasian    Male  [50-60)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
# 5                  2                         1                    2
#
#    time_in_hospital payer_code  ... citoglipton  insulin  glyburide-metformin  \
# 1                 3          ?  ...          No       Up                   No
# ...

# %%
# Filter out records where race is indicated as '?'
rc = ['Asian','AfricanAmerican','Caucasian','Hispanic','Other']
filter2 = filter1[df2['race'].isin(rc)]
# Out:
# <ipython-input-24-0ec2ff7251f3>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filter2 = filter1[df2['race'].isin(rc)]

# %%
# Total diabetesMed by specific race
subset1 = filter2.groupby(['race'])['diabetesMed'].count().sort_index(ascending=True)
subset1
# Out:
# race
# AfricanAmerican    14798
# Asian                475
# Caucasian          58450
# Hispanic            1551
# Other               1218
# Name: diabetesMed, dtype: int64

# %%
# Bar chart of total number of racial demographics who take diabetesMed
ax = subset1.sort_values(ascending=False).plot(kind='bar',color='pink')
ax.set(xlabel='Diabetes Medication', ylabel='Race', title='Total number of Diabetes Medication taken by race')
ax.bar_label(ax.containers[0], label_type='edge')
# Out:
# [Text(0, 0, '58450'),
#  Text(0, 0, '14798'),
#  Text(0, 0, '1551'),
#  Text(0, 0, '1218'),
#  Text(0, 0, '475')]

# %%
# Total number of diabetesMed taken by age group in dataset
subset2 = filter1.groupby(['age'])['diabetesMed'].count()
subset2
# Out:
# age
# [0-10)        133
# [10-20)       600
# [20-30)      1315
# [30-40)      2849
# [40-50)      7405
# [50-60)     13401
# [60-70)     17611
# [70-80)     20191
# [80-90)     12914
# [90-100)     1944
# Name: diabetesMed, dtype: int64

# %%
# Pie chart of total number of diabetesMed taken by age grounp
ax = subset2.sort_values(ascending=False).plot(kind='barh',color=['blue','red','yellow','orange','purple','magenta','grey','green','black','pink'])
ax.set(xlabel='Diabetes Medication', ylabel='Age Group', title='Total number of Diabetes Medication taken by age group')
ax.bar_label(ax.containers[0], label_type='edge')
# Out:
# [Text(0, 0, '20191'),
#  Text(0, 0, '17611'),
#  Text(0, 0, '13401'),
#  Text(0, 0, '12914'),
#  Text(0, 0, '7405'),
#  Text(0, 0, '2849'),
#  Text(0, 0, '1944'),
#  Text(0, 0, '1315'),
#  Text(0, 0, '600'),
#  Text(0, 0, '133')]

# %%
# Find number of medications prescribed to patients taking diabetes medication by age
subset3= filter1.groupby(['age'])['num_medications'].describe()
subset3
# Out:
#             count       mean       std  min   25%   50%   75%   max
# age
# [0-10)      133.0   6.586466  3.923758  2.0   4.0   6.0   8.0  34.0
# [10-20)     600.0   8.426667  5.261568  1.0   5.0   7.0  11.0  34.0
# [20-30)    1315.0  12.250190  7.064106  1.0   7.0  11.0  16.0  65.0
# [30-40)    2849.0  14.641629  7.703446  1.0   9.0  13.0  18.0  63.0
# [40-50)    7405.0  16.192032  8.130511  1.0  11.0  15.0  20.0  68.0
# [50-60)   13401.0  17.426759  8.707230  1.0  11.0  16.0  22.0  79.0
# [60-70)   17611.0  18.004770  8.803043  1.0  12.0  16.0  22.0  81.0
# [70-80)   20191.0  17.265911  8.144179  1.0  12.0  16.0  21.0  74.0
# [80-90)   12914.0  16.180347  7.076897  1.0  11.0  15.0  20.0  65.0
# [90-100)   1944.0  14.779321  6.193082  2.0  10.0  14.0  19.0  42.0

# %%
# Filter by specific value(s)
filter2 = df2[(df['age'] == '[70-80)')]
filter2.head(5)
# Out:
#     encounter_id  patient_nbr             race  gender      age  \
# 7          63768    114882984        Caucasian    Male  [70-80)
# 18         89682    107389323  AfricanAmerican    Male  [70-80)
# 19        148530     69422211                ?    Male  [70-80)
# 22        182796     63000108  AfricanAmerican  Female  [70-80)
# 24        216156     62718876  AfricanAmerican  Female  [70-80)
#
#     admission_type_id  discharge_disposition_id  admission_source_id  \
# 7                   1                         1                    7
# 18                  1                         1                    7
# 19                  3                         6                    2
# 22                  2                         1                    4
# 24                  3                         1                    2
#
#     time_in_hospital payer_code  ... citoglipton  insulin  \
# 7                  5          ?  ...          No       No
# ...

# %%
filter2.groupby(['age'])['admission_type_id'].value_counts().sort_index(ascending=True)
# Out:
# age      admission_type_id
# [70-80)  1                    13474
#          2                     4639
#          3                     5067
#          4                        2
#          5                     1344
#          6                     1462
#          7                        2
#          8                       78
# Name: admission_type_id, dtype: int64

# %% [markdown]
# Summary: From the dataset, I attempted to learn more about the general demographics (race, gender, age) of patients who take diabetes medication.
